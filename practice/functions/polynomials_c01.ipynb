# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadArshd/calculusWithPython/blob/practice/practice/functions/polynomials_c01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
np.set_printoptions(suppress=True)

# %%
xDomain = [-6, 6]
resolution = .5
n_coefs = np.random.randn(4)
n_x = np.arange(xDomain[0], xDomain[1]+resolution, resolution)
n_y = np.zeros(len(x))
fname = '$y = '
for i,c in enumerate(n_coefs):
  n_y += c*n_x**i
  fname += '+ '[int(c<0)] + f'{c:.2f}x^{i}'
n_y, n_coefs
# Out:
# (array([ 112.43582432,   85.22762935,   62.66471028,   44.31922304,
#           29.76332358,   18.56916785,   10.3089118 ,    4.55471136,
#            0.87872248,   -1.14689888,   -1.94999679,   -1.9584153 ,
#           -1.59999846,   -1.30259033,   -1.49403496,   -2.60217641,
#           -5.05485873,   -9.27992598,  -15.7052222 ,  -24.75859146,
#          -36.86787781,  -52.46092531,  -71.965578  ,  -95.80967994,
#         -124.42107519]),
#  array([-1.59999846,  0.79843965, -0.12201742, -0.57045874]))

# %%
plt.plot(n_x, n_y)
plt.title(fname + '$')
plt.grid()
plt.xlim(xDomain[0], xDomain[1])
plt.xlabel('x')
plt.ylabel('y=f(x)')
plt.show()

# %%
from sympy import symbols
s_x = symbols('x')

# %%
nume = s_x**2 - 2*s_x
deno = s_x**2 - 4
s_f = nume / deno
s_f
# Out:
# (x**2 - 2*x)/(x**2 - 4)

# %%
sym.plot(s_f, (s_x, -3, 3), ylim=[-10, 10], title=f'$y= {sym.latex(s_f)}$')
